# %% [markdown]
# # Primero instalamos las librerías de importancia.
# ## Para ello, utilizamos el comando pip install, que significa "Programa Instalador de Paquetes", y usamos la función llamada "install" para instalar las librerías necesarias.
# ## Las librerías son las siguientes con sus funciones generales:
# - **scikit-learn**: Modelos de Machine Learning.
# - **seaborn**: Realizar gráficos más avanzados, parecido a ggplot2.
# - **matplotlib**: Realizar gráficos, alternativa a ggplot2.
# - **pandas**: Trabajar con estructuras de datos, similar a tidyverse.
# - **numpy**: Trabajar con arreglos y matrices, más tidyverse.
# - **python-Levenshtein**: Calcular la distancia de Levenshtein, que sirve para autocorregir errores de tipado.

# %%
pip install scikit-learn seaborn matplotlib pandas numpy python-Levenshtein
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.5.1)
# Requirement already satisfied: seaborn in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.8.2)
# Requirement already satisfied: pandas in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.1.0)
# Requirement already satisfied: numpy in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.24.3)
# Requirement already satisfied: python-Levenshtein in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.26.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: Levenshtein==0.26.0 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-Levenshtein) (0.26.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Levenshtein==0.26.0->python-Levenshtein) (3.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\hack\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Una vez instalado, las debemos de tener en nuestro sistema, similar al instalador de R. No obstante, para poder utilizarlas, debemos de importarlas. Para ello, utilizamos la función "import" y el nombre de la librería.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import Levenshtein as Lev

# %% [markdown]
# La sintaxis del código es la siguiente:
#
# - import: función que importa la librería.
# - as: función que nos permite nombrar la librería o un objeto de la forma que queramos.
#
# Un punto importante es que podemos nombrar un acrónimo de las librerías a trabajar de la forma que queramos. Por ejemplo, para la librería pandas, podemos nombrarla como pd, para numpy como np, y así sucesivamente. Esto se hace para no tener que escribir el nombre completo de la librería cada vez que la necesitemos. Sin embargo, es bastante común encontrar acrónimos ya establecidos, como pd para pandas, np para numpy, sns para seaborn, plt para matplotlib, etc.
#
# En lo personal, me gusta cargar todas las librerías que pueda utilizar de manera regular. Para este caso, seaborn y matplotlib son librerías que hacen gráficos, pero por tiempo y objetivos, no las utilizaré.
#
# Ahora, tenemos que cargar nuestra base de datos a trabajar. Para ello, utilizamos la función "pd.read_csv" y colocamos el nombre del archivo que queremos cargar. En este caso, el archivo se llama "BD_CM.csv".
#
# Es importante señalar que la forma de nombrar las bases de datos es bastante personal, puedes nomrbarlas como quieras. Sin embargo, es recomendable que el nombre sea lo más descriptivo posible para que puedas recordar qué contiene la base de datos, si es que trabajas con varias bases de datos a la vez. En este caso, bd_CM significa Base de Datos de Cáncer de Mama. Un punto que me gusta llevar a cabo, es utilizar nombres genéricos de mis bases de datos para que pueda reutilizar el código en otras bases de datos. Para ello, suelo nombrarla como bd_1, y para cada transformación importante que hago, creo una nueva base de datos para evitar sobreescribir la base de datos original y tener que recargar todo de nuevo.

# %%
bd_1 = pd.read_csv('bd_CM.csv', sep=';')
bd_1.to_csv("bd_1.csv", index=False)
bd_1.head(5)
# Out:
#   country  overall_survival_time_months  age_at_diagnosis_years  \
# 0  mexico                     84.633333                   43.19
# 1     usa                    163.700000                   48.87
# 2  canada                    164.933333                   47.68
# 3   mexic                     41.366667                   76.97
# 4     USA                      7.800000                   78.77
#
#    lymph_nodes_examined_positive cellularity estrogen_receptors_ihc  \
# 0                              0        High                Positve
# 1                              1        High                Positve
# 2                              3    Moderate                Positve
# 3                              8        High                Positve
# 4                              0    Moderate                Positve
#
#   menopausal_state claudin_subtype     vital_status  \
# 0              Pre            LumA           Living
# 1              Pre            LumB  Died of Disease
# 2              Pre            LumB           Living
# 3             Post            LumB  Died of Disease
# 4             Post            LumB  Died of Disease
#
#                         cancer_type_detailed her2_status  \
# 0           Breast Invasive Ductal Carcinoma    Negative
# 1           Breast Invasive Ductal Carcinoma    Negative
# 2  Breast Mixed Ductal and Lobular Carcinoma    Negative
# 3  Breast Mixed Ductal and Lobular Carcinoma    Negative
# 4           Breast Invasive Ductal Carcinoma    Negative
#
#   progesterone_receptors_status  tumor_size_mm  CT_responde
# 0                      Positive           10.0            0
# 1                      Positive           15.0            0
# 2                      Positive           25.0            0
# 3                      Positive           40.0            0
# 4                      Positive           31.0            0

# %% [markdown]
# El código anterior tiene la siguiente sintaxis:
# - **pd.read_csv("BD_CM.csv")**: Carga la base de datos "BD_CM.csv" y la guarda en la variable "bd_1". La forma llamar las funciones, a diferencia de R, es que aquí utilizamos el acrónimo de la librería y un punto para llamar la función. Por ejemplo. pd.read_csv significa que estamos llamando la función read_csv de la librería pandas, sep sirve para separar los datos, utilizando un símbolo en concreto, que lo habitual de los archivos CSV es la coma, ya que ese es el significado de CSV, Comma Separated Values.
# - **bd_1.to_csv("BD_CM.csv")**: Guarda la base de datos "bd_1" en un archivo llamado "BD_1.csv". La función to_csv sirve para guardar la base de datos en un archivo CSV. Lo que queremos es generar nuestra copia de seguridad. La función de index=False sirve para no guardar el índice de la base de datos, el índice significa la numeración de las filas de la base de datos, lo cuál es innecesario.
# - **bd_1.head()**: Muestra las primeras *n* filas de la base de datos "bd_1". De base se muestran cinco, pero podemos poner el número de filas que queramos.
#
# Ya que tenemos nuestra base cargada, con copia de seguridad y ya visualizamos que se cargó correctamente, ahora vamos a hacer un pequeño resumen.

# %%
bd_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        1830 non-null   object
#  1   overall_survival_time_months   1830 non-null   float64
#  2   age_at_diagnosis_years         1830 non-null   float64
#  3   lymph_nodes_examined_positive  1830 non-null   int64
#  4   cellularity                    1830 non-null   object
#  5   estrogen_receptors_ihc         1830 non-null   object
#  6   menopausal_state               1830 non-null   object
#  7   claudin_subtype                1830 non-null   object
#  8   vital_status                   1830 non-null   object
#  9   cancer_type_detailed           1830 non-null   object
#  10  her2_status                    1740 non-null   object
#  11  progesterone_receptors_status  1830 non-null   object
#  12  tumor_size_mm                  1830 non-null   float64
#  13  CT_responde                    1830 non-null   int64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 200.3+ KB

# %% [markdown]
# La función de "bd_1.info()" nos muestra un resumen de la base de datos (número de columnas,  filas, el tipo de dato por columna,  valores nulos). Es útil para saber qué tipo de datos tenemos y saber cómo los vamos a trabajar.
#
# Un punto importante, es que Python inicia su numeración o conteo desde el cero. Por lo tanto, si queremos seleccionar la primera columna, debemos de poner el número cero. Si, es un poco extraño...
#
# Ahora, vamos a ver los valores únicos de cada columna, esto para ver si existen errores de tipado o cosas raras...

# %%
for i, col in enumerate(bd_1.columns):
    print(f"La variable '{col}', con el identificador {i}, tiene los valores únicos siguientes: {bd_1[col].unique()}")
# Out:
# La variable 'country', con el identificador 0, tiene los valores únicos siguientes: ['mexico' 'usa' 'canada' 'mexic' 'USA' 'Caada' 'Canada']
# La variable 'overall_survival_time_months', con el identificador 1, tiene los valores únicos siguientes: [ 84.63333333 163.7        164.9333333  ... 175.9666667   86.23333333
#  201.9       ]
# La variable 'age_at_diagnosis_years', con el identificador 2, tiene los valores únicos siguientes: [43.19 48.87 47.68 ... 43.1  42.88 60.02]
# La variable 'lymph_nodes_examined_positive', con el identificador 3, tiene los valores únicos siguientes: [ 0  1  3  8 24  4 16  5 14  6  2  9 22  7 21 13 12 25 10 41 15 11 19 17
#  18 23 26 20 31 33 45]
# La variable 'cellularity', con el identificador 4, tiene los valores únicos siguientes: ['High' 'Moderate' 'Low']
# La variable 'estrogen_receptors_ihc', con el identificador 5, tiene los valores únicos siguientes: ['Positve' 'Negative']
# La variable 'menopausal_state', con el identificador 6, tiene los valores únicos siguientes: ['Pre' 'Post']
# La variable 'claudin_subtype', con el identificador 7, tiene los valores únicos siguientes: ['LumA' 'LumB' 'claudin-low' 'Her2' 'Normal' 'Basal' 'NC']
# La variable 'vital_status', con el identificador 8, tiene los valores únicos siguientes: ['Living' 'Died of Disease' 'Died of Other Causes']
# La variable 'cancer_type_detailed', con el identificador 9, tiene los valores únicos siguientes: ['Breast Invasive Ductal Carcinoma'
#  'Breast Mixed Ductal and Lobular Carcinoma'
#  'Breast Invasive Lobular Carcinoma'
#  'Breast Invasive Mixed Mucinous Carcinoma' 'Breast'
#  'Invasive Breast Carcinoma' 'Metaplastic Breast Cancer']
# La variable 'her2_status', con el identificador 10, tiene los valores únicos siguientes: ['Negative' nan 'Positive']
# La variable 'progesterone_receptors_status', con el identificador 11, tiene los valores únicos siguientes: ['Positive' 'Negative']
# La variable 'tumor_size_mm', con el identificador 12, tiene los valores únicos siguientes: [ 10.    15.    25.    40.    31.    29.    16.    28.    22.    21.
#   19.    36.    33.    23.    17.    18.    12.    24.    13.    14.
#   55.    30.    39.    34.    70.    45.    27.   150.    60.    26.
#   20.    50.     9.    35.    80.    38.    52.    44.    48.     3.
#   46.    11.    53.    47.    32.    67.    43.    42.   180.    57.
#  100.    65.    37.    90.     5.     8.   160.    84.   130.     5.5
#   62.     1.    49.    99.    68.     7.    41.     6.     2.    75.
#   51.   120.    61.    79.    71.    22.5   17.9   14.5   12.8   18.5
#   15.5   21.5   16.9   24.4   12.5   40.3   11.8   32.6   17.2   13.8
#   15.7  182.    85.    18.3   21.6   28.5   16.2    2.3   15.2   31.1
#   14.3   12.6   25.1   17.6    2.12  21.3   22.32  17.7   15.47  24.15
#   20.5 ]
# La variable 'CT_responde', con el identificador 13, tiene los valores únicos siguientes: [0 1]

# %% [markdown]
# En el código anterior hicimos un pequeño truco. Hacemos un bucle *for*, lo que hace es una especie de repetición de una acción, esto permite no tener que escribir muchas veces la misma función. La sintaxis es la siguiente:
# - **for**: función que inicia el bucle.
# - **i**: nombre de la variable que va a cambiar en cada iteración. Puedes utilizar el nombre que quieras, pero recuerda que debe de ser descriptivo. En este caso la i significa *index*. Pero puedes poner idx, tacos, perro, lo que quieras...
# - **col**: el nombre de la columna que vamos a recorrer. El nombre es igual que para *i*, puedes poner el nombre que quieras.
# - **in**: función que indica que vamos a recorrer una lista.
# - **enumerate**: función que nos permite recorrer una lista y obtener el índice de la lista. Es decir, si tenemos una lista de 10 elementos, nos va a devolver el índice de cada elemento.
# - **print**: función que nos permite imprimir en pantalla.
# - **f**: función que nos permite hacer un formato de texto. Es decir, podemos poner texto y variables en la misma línea. Aquí viene la magia, ya que podemos agregar texto y variables en la misma línea para hacerlo más bonito y descriptivo.
# - **bd_1[col].unique()**: función que nos permite obtener los valores únicos de una columna. En este caso, estamos obteniendo los valores únicos de todas las columnas gracias a nuestro bucle.
#
# Puntos importantes:
# - Las comillas nos permiten escribir texto plano, es decir, que se imprime tal cual.
# - Las llaves nos permiten poner variables en el texto, como la *i* y *col*.
# - Podemos anidar comillas simples y dobles para hacer que una función se ejecute dentro de otra función. En este caso, el poner comillas simples alrededor de *{col}* que el nombre de la columna se imprima entrecomillado.
#
# Ahora, existen variables que pueden tener muchísimos valores que pueden ser difíciles de imprimir, como las edades, pesos, o en este caso, el *tumor_size_mm**. Pero podemos imprimirla por aparte para ver todos sus datos.

# %%
bd_1.tumor_size_mm.unique()
# Out:
# array([ 10.  ,  15.  ,  25.  ,  40.  ,  31.  ,  29.  ,  16.  ,  28.  ,
#         22.  ,  21.  ,  19.  ,  36.  ,  33.  ,  23.  ,  17.  ,  18.  ,
#         12.  ,  24.  ,  13.  ,  14.  ,  55.  ,  30.  ,  39.  ,  34.  ,
#         70.  ,  45.  ,  27.  , 150.  ,  60.  ,  26.  ,  20.  ,  50.  ,
#          9.  ,  35.  ,  80.  ,  38.  ,  52.  ,  44.  ,  48.  ,   3.  ,
#         46.  ,  11.  ,  53.  ,  47.  ,  32.  ,  67.  ,  43.  ,  42.  ,
#        180.  ,  57.  , 100.  ,  65.  ,  37.  ,  90.  ,   5.  ,   8.  ,
#        160.  ,  84.  , 130.  ,   5.5 ,  62.  ,   1.  ,  49.  ,  99.  ,
#         68.  ,   7.  ,  41.  ,   6.  ,   2.  ,  75.  ,  51.  , 120.  ,
#         61.  ,  79.  ,  71.  ,  22.5 ,  17.9 ,  14.5 ,  12.8 ,  18.5 ,
#         15.5 ,  21.5 ,  16.9 ,  24.4 ,  12.5 ,  40.3 ,  11.8 ,  32.6 ,
#         17.2 ,  13.8 ,  15.7 , 182.  ,  85.  ,  18.3 ,  21.6 ,  28.5 ,
#         16.2 ,   2.3 ,  15.2 ,  31.1 ,  14.3 ,  12.6 ,  25.1 ,  17.6 ,
#          2.12,  21.3 ,  22.32,  17.7 ,  15.47,  24.15,  20.5 ])

# %% [markdown]
# Ahora, si te das cuenta, para hacer muchas cosas en python, llamamos la base datos, luego ponemos un punto, luego la variables de interés, otro punto, y luego la función que queremos hacer.
# Listo, con una función tan simple como hacer un *.unique()* después de la variable, podemos ver todos los valores únicos de una variable. Sin embargo, están desordenados, por lo que podemos ordenarlos con la función *sorted()*.

# %%
sorted(bd_1.tumor_size_mm.unique())
# Out:
# [1.0,
#  2.0,
#  2.12,
#  2.3,
#  3.0,
#  5.0,
#  5.5,
#  6.0,
#  7.0,
#  8.0,
#  9.0,
#  10.0,
#  11.0,
#  11.8,
#  12.0,
#  12.5,
#  12.6,
#  12.8,
#  13.0,
#  13.8,
#  14.0,
#  14.3,
#  14.5,
#  15.0,
#  15.2,
#  15.47,
#  15.5,
#  15.7,
#  16.0,
#  16.2,
#  16.9,
#  17.0,
#  17.2,
#  17.6,
#  17.7,
#  17.9,
#  18.0,
#  18.3,
#  18.5,
#  19.0,
#  20.0,
#  20.5,
#  21.0,
#  21.3,
#  21.5,
#  21.6,
#  22.0,
#  22.32,
#  22.5,
#  23.0,
#  24.0,
#  24.15,
#  24.4,
#  25.0,
#  25.1,
#  26.0,
#  27.0,
#  28.0,
#  28.5,
#  29.0,
#  30.0,
#  31.0,
#  31.1,
#  32.0,
#  32.6,
#  33.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  38.0,
#  39.0,
#  40.0,
#  40.3,
#  41.0,
#  42.0,
#  43.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  48.0,
#  49.0,
#  50.0,
#  51.0,
#  52.0,
#  53.0,
#  55.0,
#  57.0,
#  60.0,
#  61.0,
#  62.0,
#  65.0,
#  67.0,
#  68.0,
#  70.0,
#  71.0,
#  75.0,
#  79.0,
#  80.0,
#  84.0,
#  85.0,
#  90.0,
#  99.0,
#  100.0,
#  120.0,
#  130.0,
#  150.0,
#  160.0,
#  180.0,
#  182.0]

# %% [markdown]
# Listo! Tenemos todos nuestros datos bonitos y ordenados. Ahora, si retornamos a nuestra información general, pudimos ver que hubo un error de tipado... Alguien o "alguienes" puso "Positve" en vez de "Positive", por lo que ahora hay que corregirlo usando la función ".replace()".

# %%
bd_1.estrogen_receptors_ihc = bd_1.estrogen_receptors_ihc.replace('Positve', 'Positive')

# %% [markdown]
# La sintaxis de la función es la siguiente:
# - El signo de igual sirve para asignar un valor a una variable, que en este caso, básicamente es reemplazar un valor por otro. Naturalmente, si queremos crear una nueva copia, podemos seguir la lógica de la numeración y hacer bd_2, pero sigamos con la 1 por lo pronto.
# - **.replace**: función que nos permite reemplazar un valor por otro. Solo se debe de agregar el valor a reemplazar y el valor nuevo, en ese orden, separado por una coma, y los valores entrecomillados.
#
# Pro tip: Puede que hallas notado que todas las variables usan guiones bajos en vez de espacios. Esto es ideal para trabajar, ya que los espacios generan conflicto en la computadora y piensa que son palabras separadas. Por lo tanto, es recomendable que uses guiones bajos en vez de espacios, pero si tus variables no los tienen y las has limpiado, puede hacer la siguiente alternativa.
#
# bd_1['estrogen_receptors_ihc'] = bd_1['estrogen_receptors_ihc'].replace('Positve', 'Positive')
#
# Es decir, abrir corchetes, entrecomillar y poner el nombre la variable con feos espacios inútiles para los nombres de las variables en la computadora... y listo! Ya tienes tu variable corregida.
#
# Ahora, detectamos otro pequeño problema, es que tenemos datos vacíos en la variable de *her2_status*...
# Existen varias formas de tratar los datos vacíos, dependiendo de si es númerico o categórico, lo ideal es volver a obtener esos datos, pero si no es posible, podemos inferirlos o eliminarlos. En este caso, como no queremos perder datos valiosos, vamos a inferirlos. Para ello, usamos una variable auxiliar que tenga dicha información, que es la de *claudin_subtype*. El código es el siguiente:

# %%
mask_Her = bd_1['claudin_subtype'].str.contains('Her2', regex=False)
bd_1.loc[mask_Her & pd.isna(bd_1['her2_status']), 'her2_status'] = 'Positive'
bd_1.to_csv("bd_2.csv", index=False)

# %% [markdown]
# Lo que acabamos de hacer es crear algo llamado máscara booleana, que básicamente consiste en crear una subvariable dentro de la variable que tenga valores de verdadero o falso, dependiendo de si se cumple una condición, que es un par de observaciones en especifico, por ejemplo, si tiene el nombre exacto de "Her2". La sintaxis es la siguiente:
# - **.str.contains**: función que nos permite buscar una cadena de texto dentro de una variable. En este caso, estamos buscando la cadena de texto "Her2" dentro de la variable "claudin_subtype". El argumento de regex=False sirve para que no se busque una expresión regular, sino una cadena de texto exacta. Una expresión regular nos serviría si queremos que nos arroje un resultado positivo si tenemos una cadena de texto que contenga una palabra en específico, como "Her2" o "Her2+", "Her2 positive", etc., ya que todas contienen "Her2" dentro de ellas.
# - **bd_1.loc**: seleccionar un subconjunto de datos.
# - **pd.isna**: permite detectar valores nulos o vacíos, en la columna de "her2_status".
# -  **bd_1.to_csv("bd_2.csv", index=False)**: Guarda la base de datos transformada a una nueva base llamada "bd_2.csv", sin guardar el índice. Esto con el objetivo de evitar sobreescribir la base de datos original y tener que cargarla de nuevo.
#
# El resultado anterior, a modo de resumen, es crear un subset que detecte "Her2" en la columna de "claudin_subtype", aquellos que tengan "Her2" se pondrá ese valor en la columna de "her2_status", y va a sobreescribir los valores vacíos en la columna de "her2_status" con los valores de "claudin_subtype" que contengan "Her2".
#
# Dicho de otra forma, obtuvimos los faltantes de "her2_status" a partir de "claudin_subtype".
#
# Esto se puede aplicar a otras variables, pero es importante que puede tener errores... Otro punto de utilidad, es para extraer texto de una columna que contenga mucha información, pero hay que tener cuidado, ya que puede mencionar "Her2 resultado negativo", y esta técnica puede dar datos erróneos.
#
# Ahora, vamos a verificar lo que hemos hecho, para ello, vamos a cargar la nueva base en un objeto.

# %%
bd_2 = pd.read_csv('bd_2.csv', sep=',')
bd_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        1830 non-null   object
#  1   overall_survival_time_months   1830 non-null   float64
#  2   age_at_diagnosis_years         1830 non-null   float64
#  3   lymph_nodes_examined_positive  1830 non-null   int64
#  4   cellularity                    1830 non-null   object
#  5   estrogen_receptors_ihc         1830 non-null   object
#  6   menopausal_state               1830 non-null   object
#  7   claudin_subtype                1830 non-null   object
#  8   vital_status                   1830 non-null   object
#  9   cancer_type_detailed           1830 non-null   object
#  10  her2_status                    1830 non-null   object
#  11  progesterone_receptors_status  1830 non-null   object
#  12  tumor_size_mm                  1830 non-null   float64
#  13  CT_responde                    1830 non-null   int64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 200.3+ KB

# %% [markdown]
# Muy bien, ya tenemos nuestra base de datos con los datos faltantes de "her2_status" completados. Ahora, recordemos que algunos datos de "country" estaban mal escritos, por ejemplo, salía "mexic" o "Caada", para evitar tener que sobreescribir cada palabra de forma correcta, o buscar una a una, podemos utilizar la función de autocorrección de errores de tipado, que es la distancia de Levenshtein.
#
# Levenshtein permite anexar un diccionario propuesto y tomará eso como base para hacer una corrección de errores de tipado.

# %%
import Levenshtein
palabras_correctas  = ['Mexico', 'USA', 'Canada']
def corregir_palabra(palabra_incorrecta, palabras_correctas):
    return min(palabras_correctas, key=lambda x: Levenshtein.distance(palabra_incorrecta, x))
bd_3 = bd_2
bd_3['country'] = bd_3['country'].apply(lambda x: corregir_palabra(x, palabras_correctas))
bd_3.to_csv("bd_3.csv", index=False)
print(bd_2['country'].unique())
# Out:
# ['Mexico' 'USA' 'Canada']

# %% [markdown]
# La sintaxis es la siguiente:
# - **palabras_correctas** = ['Mexico', 'USA', 'Canada']: Creamos un objeto que contenga las palabras correctas. Nosotros usamos las palabras que necesitemos, y hay que considerar que es sensible a mayúsculas.
# - **def**: función que nos permite definir una función, puede sonar redundante, pero es forma de crear una función en Python.
# - **corregir_palabra**: nombre de la función que vamos a crear, recordemos que poner los nombres que deseemos.
# - **palabra_incorrecta**: argumento de la función que vamos a crear, es decir, la palabra que vamos a corregir.
# - **return**: función que nos permite devolver un valor, en este caso, la palabra corregida.
# - **min**: función que nos permite obtener el valor mínimo de una lista. En este caso, estamos obteniendo el valor mínimo de una lista de distancias de Levenshtein.
# - **key=lambda x**: Define una función (lambda) que calcula la distancia de edición entre la "palabra_incorrecta" y cada palabra "x" en la lista "palabras_correctas". Dicho de otra manera, es un cálculo matemático para saber que tantas letras debe detectar para corregir empleando errores de tipado (inserciones, deleciones o sustituciones).
#
# El resto de funcionesy argumentos ya los vimos, básicamente es aplicar la función, crear una nueva base e imprimirla.
#
# Y nos damos cuenta que ahora solo tenemos tres tipos de variables: "Mexico", "USA" y "Canada". Omitimos los acentos por cuestiones facilidad en la escritura.
#
# Ahora, vamos a llevar a cabo una conversión. En este caso, vamos a convertir las variables categóricas con carácter lógico a numéricas. Para ello, hacemos un truco muy sencillo con la función "replace".

# %%
bd_4 = bd_3.replace({'Positive': 1, 'Negative': 0,
                    'Pre': 0, 'Post': 1})
bd_4.head()
# Out:
#   country  overall_survival_time_months  age_at_diagnosis_years  \
# 0  Mexico                     84.633333                   43.19
# 1     USA                    163.700000                   48.87
# 2  Canada                    164.933333                   47.68
# 3  Mexico                     41.366667                   76.97
# 4     USA                      7.800000                   78.77
#
#    lymph_nodes_examined_positive cellularity  estrogen_receptors_ihc  \
# 0                              0        High                       1
# 1                              1        High                       1
# 2                              3    Moderate                       1
# 3                              8        High                       1
# 4                              0    Moderate                       1
#
#    menopausal_state claudin_subtype     vital_status  \
# 0                 0            LumA           Living
# 1                 0            LumB  Died of Disease
# 2                 0            LumB           Living
# 3                 1            LumB  Died of Disease
# 4                 1            LumB  Died of Disease
#
#                         cancer_type_detailed  her2_status  \
# 0           Breast Invasive Ductal Carcinoma            0
# 1           Breast Invasive Ductal Carcinoma            0
# 2  Breast Mixed Ductal and Lobular Carcinoma            0
# 3  Breast Mixed Ductal and Lobular Carcinoma            0
# 4           Breast Invasive Ductal Carcinoma            0
#
#    progesterone_receptors_status  tumor_size_mm  CT_responde
# 0                              1           10.0            0
# 1                              1           15.0            0
# 2                              1           25.0            0
# 3                              1           40.0            0
# 4                              1           31.0            0

# %% [markdown]
# La sintaxis es muy simple, tomamos la función "replace" y damos los argumentos con el antes y el después de lo que queremos reemplazar separado por dos puntos. Entonces "Positive" se convierte en 1 y "Negative" en 0, "Pre" en 0 y "Post" en 1.
#
# Ahora, vamos a hacer un función muy poderosa y útil, que es la de "get_dummies". Esta función nos permite convertir variables categóricas en variables dummy, es decir, variables binarias. Lo que hacemos es convertir toda la base de datos con variables de tipo caracter a variables binarias, y creará una nueva columna para cada una de ella. Por lo que hay que tener algo de cuidado, ya que si una columna tiene, digamos, 20 variables, se crearán 20 columnas nuevas...

# %%
bd_5 = pd.get_dummies(bd_4, 
                      columns=[bd_4.columns[0], 
                               bd_4.columns[4],
                               bd_4.columns[7], 
                               bd_4.columns[8],
                               bd_4.columns[9]],
                      dtype=int)
for i, col in enumerate(bd_5.columns):
    print(f" {i} - {col}: {bd_5[col].unique()}")
# Out:
#  0 - overall_survival_time_months: [ 84.63333333 163.7        164.9333333  ... 175.9666667   86.23333333
#  201.9       ]
#  1 - age_at_diagnosis_years: [43.19 48.87 47.68 ... 43.1  42.88 60.02]
#  2 - lymph_nodes_examined_positive: [ 0  1  3  8 24  4 16  5 14  6  2  9 22  7 21 13 12 25 10 41 15 11 19 17
#  18 23 26 20 31 33 45]
#  3 - estrogen_receptors_ihc: [1 0]
#  4 - menopausal_state: [0 1]
#  5 - her2_status: [0 1]
#  6 - progesterone_receptors_status: [1 0]
#  7 - tumor_size_mm: [ 10.    15.    25.    40.    31.    29.    16.    28.    22.    21.
#   19.    36.    33.    23.    17.    18.    12.    24.    13.    14.
#   55.    30.    39.    34.    70.    45.    27.   150.    60.    26.
#   20.    50.     9.    35.    80.    38.    52.    44.    48.     3.
#   46.    11.    53.    47.    32.    67.    43.    42.   180.    57.
#  100.    65.    37.    90.     5.     8.   160.    84.   130.     5.5
#   62.     1.    49.    99.    68.     7.    41.     6.     2.    75.
#   51.   120.    61.    79.    71.    22.5   17.9   14.5   12.8   18.5
#   15.5   21.5   16.9   24.4   12.5   40.3   11.8   32.6   17.2   13.8
#   15.7  182.    85.    18.3   21.6   28.5   16.2    2.3   15.2   31.1
#   14.3   12.6   25.1   17.6    2.12  21.3   22.32  17.7   15.47  24.15
#   20.5 ]
#  8 - CT_responde: [0 1]
#  9 - country_Canada: [0 1]
#  10 - country_Mexico: [1 0]
#  11 - country_USA: [0 1]
#  12 - cellularity_High: [1 0]
#  13 - cellularity_Low: [0 1]
#  14 - cellularity_Moderate: [0 1]
#  15 - claudin_subtype_Basal: [0 1]
#  16 - claudin_subtype_Her2: [0 1]
#  17 - claudin_subtype_LumA: [1 0]
#  18 - claudin_subtype_LumB: [0 1]
#  19 - claudin_subtype_NC: [0 1]
#  20 - claudin_subtype_Normal: [0 1]
#  21 - claudin_subtype_claudin-low: [0 1]
#  22 - vital_status_Died of Disease: [0 1]
#  23 - vital_status_Died of Other Causes: [0 1]
#  24 - vital_status_Living: [1 0]
#  25 - cancer_type_detailed_Breast: [0 1]
#  26 - cancer_type_detailed_Breast Invasive Ductal Carcinoma: [1 0]
#  27 - cancer_type_detailed_Breast Invasive Lobular Carcinoma: [0 1]
#  28 - cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma: [0 1]
#  29 - cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma: [0 1]
#  30 - cancer_type_detailed_Invasive Breast Carcinoma: [0 1]
#  31 - cancer_type_detailed_Metaplastic Breast Cancer: [0 1]

# %% [markdown]
# La sintaxis es la siguiente es relativamente simple, entre corchetes se encuentra el número de la variable que queremos convertir, recordemos que empieza en 0. Hacemos un bucle, pero ahora agregamos la función "enumarate" para obtener el índice de la variable y el nombre de la variable. Finalmente imprimimos.
#
# Ahora, tendremos que hacer una pequeña limpieza, que puede llevar incluso meses de tiempo según las necesidades del estudio y objetivo del modelo, que consiste en ver variables que no aportan información, o que es repetitivo...
#
# Veamos un solo método de prepocesado de datos en este aspecto, que consiste en una matriz de correlación.
#
# Nota: una matriz de correlación no es la única ni la mejor manera de evaluar si una variable tiene relación con otra, existen otros métodos que deben evaluarse por cada variable y por cada estudio.

# %%
pd.set_option('display.max_columns', None)
matriz_correlacion = bd_5.corr()
sorted_correlacion = matriz_correlacion.unstack().sort_values(ascending=False)
print(sorted_correlacion)
# Out:
# overall_survival_time_months                                    overall_survival_time_months                                      1.000000
# claudin_subtype_Her2                                            claudin_subtype_Her2                                              1.000000
# estrogen_receptors_ihc                                          estrogen_receptors_ihc                                            1.000000
# menopausal_state                                                menopausal_state                                                  1.000000
# her2_status                                                     her2_status                                                       1.000000
# progesterone_receptors_status                                   progesterone_receptors_status                                     1.000000
# tumor_size_mm                                                   tumor_size_mm                                                     1.000000
# CT_responde                                                     CT_responde                                                       1.000000
# country_Canada                                                  country_Canada                                                    1.000000
# country_Mexico                                                  country_Mexico                                                    1.000000
# country_USA                                                     country_USA                                                       1.000000
# cellularity_High                                                cellularity_High                                                  1.000000
# cellularity_Low                                                 cellularity_Low                                                   1.000000
# cellularity_Moderate                                            cellularity_Moderate                                              1.000000
# claudin_subtype_Basal                                           claudin_subtype_Basal                                             1.000000
# claudin_subtype_LumA                                            claudin_subtype_LumA                                              1.000000
# age_at_diagnosis_years                                          age_at_diagnosis_years                                            1.000000
# claudin_subtype_LumB                                            claudin_subtype_LumB                                              1.000000
# claudin_subtype_NC                                              claudin_subtype_NC                                                1.000000
# claudin_subtype_Normal                                          claudin_subtype_Normal                                            1.000000
# claudin_subtype_claudin-low                                     claudin_subtype_claudin-low                                       1.000000
# vital_status_Died of Disease                                    vital_status_Died of Disease                                      1.000000
# vital_status_Died of Other Causes                               vital_status_Died of Other Causes                                 1.000000
# vital_status_Living                                             vital_status_Living                                               1.000000
# cancer_type_detailed_Breast                                     cancer_type_detailed_Breast                                       1.000000
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           cancer_type_detailed_Breast Invasive Ductal Carcinoma             1.000000
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          cancer_type_detailed_Breast Invasive Lobular Carcinoma            1.000000
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     1.000000
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    1.000000
# cancer_type_detailed_Invasive Breast Carcinoma                  cancer_type_detailed_Invasive Breast Carcinoma                    1.000000
# lymph_nodes_examined_positive                                   lymph_nodes_examined_positive                                     1.000000
# cancer_type_detailed_Metaplastic Breast Cancer                  cancer_type_detailed_Metaplastic Breast Cancer                    1.000000
# claudin_subtype_Her2                                            her2_status                                                       0.785596
# her2_status                                                     claudin_subtype_Her2                                              0.785596
# age_at_diagnosis_years                                          menopausal_state                                                  0.741913
# menopausal_state                                                age_at_diagnosis_years                                            0.741913
# progesterone_receptors_status                                   estrogen_receptors_ihc                                            0.458253
# estrogen_receptors_ihc                                          progesterone_receptors_status                                     0.458253
# overall_survival_time_months                                    vital_status_Living                                               0.392134
# vital_status_Living                                             overall_survival_time_months                                      0.392134
# vital_status_Died of Other Causes                               age_at_diagnosis_years                                            0.380785
# age_at_diagnosis_years                                          vital_status_Died of Other Causes                                 0.380785
# estrogen_receptors_ihc                                          claudin_subtype_LumA                                              0.373044
# claudin_subtype_LumA                                            estrogen_receptors_ihc                                            0.373044
#                                                                 progesterone_receptors_status                                     0.358632
# progesterone_receptors_status                                   claudin_subtype_LumA                                              0.358632
# estrogen_receptors_ihc                                          age_at_diagnosis_years                                            0.311442
# age_at_diagnosis_years                                          estrogen_receptors_ihc                                            0.311442
# estrogen_receptors_ihc                                          claudin_subtype_LumB                                              0.273899
# claudin_subtype_LumB                                            estrogen_receptors_ihc                                            0.273899
# menopausal_state                                                estrogen_receptors_ihc                                            0.265838
# estrogen_receptors_ihc                                          menopausal_state                                                  0.265838
# tumor_size_mm                                                   lymph_nodes_examined_positive                                     0.263849
# lymph_nodes_examined_positive                                   tumor_size_mm                                                     0.263849
# vital_status_Died of Other Causes                               menopausal_state                                                  0.246121
# menopausal_state                                                vital_status_Died of Other Causes                                 0.246121
# vital_status_Died of Disease                                    lymph_nodes_examined_positive                                     0.243279
# lymph_nodes_examined_positive                                   vital_status_Died of Disease                                      0.243279
# cellularity_Low                                                 claudin_subtype_Normal                                            0.206853
# claudin_subtype_Normal                                          cellularity_Low                                                   0.206853
# tumor_size_mm                                                   vital_status_Died of Disease                                      0.180701
# vital_status_Died of Disease                                    tumor_size_mm                                                     0.180701
# age_at_diagnosis_years                                          claudin_subtype_LumB                                              0.176454
# claudin_subtype_LumB                                            age_at_diagnosis_years                                            0.176454
# vital_status_Died of Disease                                    her2_status                                                       0.152669
# her2_status                                                     vital_status_Died of Disease                                      0.152669
# claudin_subtype_LumB                                            menopausal_state                                                  0.150368
# menopausal_state                                                claudin_subtype_LumB                                              0.150368
# claudin_subtype_LumA                                            overall_survival_time_months                                      0.146428
# overall_survival_time_months                                    claudin_subtype_LumA                                              0.146428
# estrogen_receptors_ihc                                          vital_status_Died of Other Causes                                 0.143227
# vital_status_Died of Other Causes                               estrogen_receptors_ihc                                            0.143227
# overall_survival_time_months                                    progesterone_receptors_status                                     0.137783
# progesterone_receptors_status                                   overall_survival_time_months                                      0.137783
# cellularity_High                                                claudin_subtype_LumB                                              0.136771
# claudin_subtype_LumB                                            cellularity_High                                                  0.136771
# claudin_subtype_claudin-low                                     cellularity_Low                                                   0.129761
# cellularity_Low                                                 claudin_subtype_claudin-low                                       0.129761
# estrogen_receptors_ihc                                          cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.129644
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  estrogen_receptors_ihc                                            0.129644
# claudin_subtype_Basal                                           cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.128207
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           claudin_subtype_Basal                                             0.128207
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  claudin_subtype_LumA                                              0.125594
# claudin_subtype_LumA                                            cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.125594
#                                                                 vital_status_Died of Other Causes                                 0.123380
# vital_status_Died of Other Causes                               claudin_subtype_LumA                                              0.123380
# vital_status_Died of Disease                                    claudin_subtype_Her2                                              0.122295
# claudin_subtype_Her2                                            vital_status_Died of Disease                                      0.122295
# her2_status                                                     lymph_nodes_examined_positive                                     0.116494
# lymph_nodes_examined_positive                                   her2_status                                                       0.116494
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  progesterone_receptors_status                                     0.116109
# progesterone_receptors_status                                   cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.116109
# cellularity_Moderate                                            estrogen_receptors_ihc                                            0.115039
# estrogen_receptors_ihc                                          cellularity_Moderate                                              0.115039
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           her2_status                                                       0.111294
# her2_status                                                     cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.111294
# cellularity_Moderate                                            claudin_subtype_LumA                                              0.108150
# claudin_subtype_LumA                                            cellularity_Moderate                                              0.108150
# progesterone_receptors_status                                   claudin_subtype_LumB                                              0.107575
# claudin_subtype_LumB                                            progesterone_receptors_status                                     0.107575
# claudin_subtype_Her2                                            CT_responde                                                       0.105324
# CT_responde                                                     claudin_subtype_Her2                                              0.105324
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          claudin_subtype_Normal                                            0.104894
# claudin_subtype_Normal                                          cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.104894
# estrogen_receptors_ihc                                          overall_survival_time_months                                      0.096616
# overall_survival_time_months                                    estrogen_receptors_ihc                                            0.096616
# age_at_diagnosis_years                                          claudin_subtype_LumA                                              0.096311
# claudin_subtype_LumA                                            age_at_diagnosis_years                                            0.096311
# vital_status_Died of Other Causes                               progesterone_receptors_status                                     0.090535
# progesterone_receptors_status                                   vital_status_Died of Other Causes                                 0.090535
# vital_status_Living                                             claudin_subtype_claudin-low                                       0.087606
# claudin_subtype_claudin-low                                     vital_status_Living                                               0.087606
# claudin_subtype_LumB                                            vital_status_Died of Disease                                      0.084591
# vital_status_Died of Disease                                    claudin_subtype_LumB                                              0.084591
# age_at_diagnosis_years                                          progesterone_receptors_status                                     0.081764
# progesterone_receptors_status                                   age_at_diagnosis_years                                            0.081764
# claudin_subtype_Her2                                            cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.080833
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           claudin_subtype_Her2                                              0.080833
# tumor_size_mm                                                   her2_status                                                       0.078889
# her2_status                                                     tumor_size_mm                                                     0.078889
# lymph_nodes_examined_positive                                   claudin_subtype_Her2                                              0.076534
# claudin_subtype_Her2                                            lymph_nodes_examined_positive                                     0.076534
#                                                                 tumor_size_mm                                                     0.074794
# tumor_size_mm                                                   claudin_subtype_Her2                                              0.074794
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   claudin_subtype_LumB                                              0.074422
# claudin_subtype_LumB                                            cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.074422
# tumor_size_mm                                                   claudin_subtype_Basal                                             0.073866
# claudin_subtype_Basal                                           tumor_size_mm                                                     0.073866
# vital_status_Died of Other Causes                               CT_responde                                                       0.071866
# CT_responde                                                     vital_status_Died of Other Causes                                 0.071866
# cancer_type_detailed_Metaplastic Breast Cancer                  claudin_subtype_claudin-low                                       0.070794
# claudin_subtype_claudin-low                                     cancer_type_detailed_Metaplastic Breast Cancer                    0.070794
# claudin_subtype_Basal                                           CT_responde                                                       0.070401
# CT_responde                                                     claudin_subtype_Basal                                             0.070401
# estrogen_receptors_ihc                                          cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.070191
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          estrogen_receptors_ihc                                            0.070191
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           cellularity_High                                                  0.069842
# cellularity_High                                                cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.069842
# claudin_subtype_Basal                                           cellularity_High                                                  0.069386
# cellularity_High                                                claudin_subtype_Basal                                             0.069386
# her2_status                                                     CT_responde                                                       0.069002
# CT_responde                                                     her2_status                                                       0.069002
# cellularity_Moderate                                            cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.068773
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  cellularity_Moderate                                              0.068773
# vital_status_Living                                             claudin_subtype_LumA                                              0.067095
# claudin_subtype_LumA                                            vital_status_Living                                               0.067095
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          tumor_size_mm                                                     0.066873
# tumor_size_mm                                                   cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.066873
# claudin_subtype_Her2                                            cellularity_High                                                  0.065233
# cellularity_High                                                claudin_subtype_Her2                                              0.065233
# CT_responde                                                     overall_survival_time_months                                      0.062718
# overall_survival_time_months                                    CT_responde                                                       0.062718
# cellularity_High                                                tumor_size_mm                                                     0.060518
# tumor_size_mm                                                   cellularity_High                                                  0.060518
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   estrogen_receptors_ihc                                            0.056129
# estrogen_receptors_ihc                                          cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.056129
# vital_status_Died of Other Causes                               cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.055461
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  vital_status_Died of Other Causes                                 0.055461
# vital_status_Died of Disease                                    claudin_subtype_Basal                                             0.054945
# claudin_subtype_Basal                                           vital_status_Died of Disease                                      0.054945
# vital_status_Living                                             cancer_type_detailed_Breast                                       0.051082
# cancer_type_detailed_Breast                                     vital_status_Living                                               0.051082
# menopausal_state                                                claudin_subtype_LumA                                              0.051072
# claudin_subtype_LumA                                            menopausal_state                                                  0.051072
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  age_at_diagnosis_years                                            0.050563
# age_at_diagnosis_years                                          cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.050563
# menopausal_state                                                cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.050375
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  menopausal_state                                                  0.050375
# claudin_subtype_LumA                                            cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.050224
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          claudin_subtype_LumA                                              0.050224
# claudin_subtype_NC                                              age_at_diagnosis_years                                            0.049315
# age_at_diagnosis_years                                          claudin_subtype_NC                                                0.049315
# cellularity_Low                                                 cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.048868
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   cellularity_Low                                                   0.048868
# country_Canada                                                  claudin_subtype_NC                                                0.046931
# claudin_subtype_NC                                              country_Canada                                                    0.046931
# CT_responde                                                     vital_status_Died of Disease                                      0.046020
# vital_status_Died of Disease                                    CT_responde                                                       0.046020
# age_at_diagnosis_years                                          cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.044940
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   age_at_diagnosis_years                                            0.044940
# cellularity_Low                                                 cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.044816
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          cellularity_Low                                                   0.044816
# menopausal_state                                                cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.044437
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          menopausal_state                                                  0.044437
# cancer_type_detailed_Breast                                     claudin_subtype_Normal                                            0.044008
# claudin_subtype_Normal                                          cancer_type_detailed_Breast                                       0.044008
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          age_at_diagnosis_years                                            0.043673
# age_at_diagnosis_years                                          cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.043673
# tumor_size_mm                                                   age_at_diagnosis_years                                            0.043324
# age_at_diagnosis_years                                          tumor_size_mm                                                     0.043324
# cellularity_Low                                                 claudin_subtype_NC                                                0.042154
# claudin_subtype_NC                                              cellularity_Low                                                   0.042154
# country_USA                                                     claudin_subtype_LumB                                              0.041262
# claudin_subtype_LumB                                            country_USA                                                       0.041262
# CT_responde                                                     cellularity_High                                                  0.041160
# cellularity_High                                                CT_responde                                                       0.041160
# cancer_type_detailed_Metaplastic Breast Cancer                  vital_status_Died of Other Causes                                 0.040294
# vital_status_Died of Other Causes                               cancer_type_detailed_Metaplastic Breast Cancer                    0.040294
# tumor_size_mm                                                   claudin_subtype_LumB                                              0.040158
# claudin_subtype_LumB                                            tumor_size_mm                                                     0.040158
# claudin_subtype_Normal                                          progesterone_receptors_status                                     0.038953
# progesterone_receptors_status                                   claudin_subtype_Normal                                            0.038953
# country_USA                                                     cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.038951
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          country_USA                                                       0.038951
# vital_status_Living                                             cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.038534
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   vital_status_Living                                               0.038534
# overall_survival_time_months                                    cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.038138
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  overall_survival_time_months                                      0.038138
# progesterone_receptors_status                                   menopausal_state                                                  0.037016
# menopausal_state                                                progesterone_receptors_status                                     0.037016
# country_USA                                                     cancer_type_detailed_Metaplastic Breast Cancer                    0.036964
# cancer_type_detailed_Metaplastic Breast Cancer                  country_USA                                                       0.036964
# cellularity_Moderate                                            cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.036098
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   cellularity_Moderate                                              0.036098
# CT_responde                                                     claudin_subtype_LumA                                              0.035930
# claudin_subtype_LumA                                            CT_responde                                                       0.035930
# menopausal_state                                                cancer_type_detailed_Breast                                       0.034449
# cancer_type_detailed_Breast                                     menopausal_state                                                  0.034449
# claudin_subtype_claudin-low                                     cellularity_Moderate                                              0.034157
# cellularity_Moderate                                            claudin_subtype_claudin-low                                       0.034157
# lymph_nodes_examined_positive                                   claudin_subtype_LumB                                              0.032746
# claudin_subtype_LumB                                            lymph_nodes_examined_positive                                     0.032746
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           country_Canada                                                    0.031667
# country_Canada                                                  cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.031667
# overall_survival_time_months                                    country_USA                                                       0.031629
# country_USA                                                     overall_survival_time_months                                      0.031629
# country_Mexico                                                  cancer_type_detailed_Breast                                       0.031536
# cancer_type_detailed_Breast                                     country_Mexico                                                    0.031536
# cancer_type_detailed_Invasive Breast Carcinoma                  claudin_subtype_Basal                                             0.031108
# claudin_subtype_Basal                                           cancer_type_detailed_Invasive Breast Carcinoma                    0.031108
# vital_status_Died of Other Causes                               overall_survival_time_months                                      0.030789
# overall_survival_time_months                                    vital_status_Died of Other Causes                                 0.030789
# cellularity_Low                                                 cancer_type_detailed_Invasive Breast Carcinoma                    0.030656
# cancer_type_detailed_Invasive Breast Carcinoma                  cellularity_Low                                                   0.030656
# estrogen_receptors_ihc                                          claudin_subtype_NC                                                0.030625
# claudin_subtype_NC                                              estrogen_receptors_ihc                                            0.030625
# CT_responde                                                     claudin_subtype_NC                                                0.030279
# claudin_subtype_NC                                              CT_responde                                                       0.030279
# cellularity_Moderate                                            claudin_subtype_Normal                                            0.029897
# claudin_subtype_Normal                                          cellularity_Moderate                                              0.029897
# claudin_subtype_NC                                              menopausal_state                                                  0.029799
# menopausal_state                                                claudin_subtype_NC                                                0.029799
# vital_status_Living                                             cellularity_Low                                                   0.029685
# cellularity_Low                                                 vital_status_Living                                               0.029685
# cellularity_Moderate                                            cancer_type_detailed_Metaplastic Breast Cancer                    0.029674
# cancer_type_detailed_Metaplastic Breast Cancer                  cellularity_Moderate                                              0.029674
# progesterone_receptors_status                                   cellularity_Low                                                   0.029528
# cellularity_Low                                                 progesterone_receptors_status                                     0.029528
# cancer_type_detailed_Breast                                     progesterone_receptors_status                                     0.029324
# progesterone_receptors_status                                   cancer_type_detailed_Breast                                       0.029324
# menopausal_state                                                cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.028923
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   menopausal_state                                                  0.028923
# lymph_nodes_examined_positive                                   claudin_subtype_claudin-low                                       0.027890
# claudin_subtype_claudin-low                                     lymph_nodes_examined_positive                                     0.027890
# overall_survival_time_months                                    cellularity_Moderate                                              0.027750
# cellularity_Moderate                                            overall_survival_time_months                                      0.027750
# country_USA                                                     cancer_type_detailed_Invasive Breast Carcinoma                    0.027748
# cancer_type_detailed_Invasive Breast Carcinoma                  country_USA                                                       0.027748
# vital_status_Living                                             progesterone_receptors_status                                     0.027056
# progesterone_receptors_status                                   vital_status_Living                                               0.027056
# lymph_nodes_examined_positive                                   cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.026993
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          lymph_nodes_examined_positive                                     0.026993
# her2_status                                                     cancer_type_detailed_Invasive Breast Carcinoma                    0.026902
# cancer_type_detailed_Invasive Breast Carcinoma                  her2_status                                                       0.026902
# cellularity_Moderate                                            age_at_diagnosis_years                                            0.026384
# age_at_diagnosis_years                                          cellularity_Moderate                                              0.026384
# country_Mexico                                                  vital_status_Died of Disease                                      0.025622
# vital_status_Died of Disease                                    country_Mexico                                                    0.025622
# cellularity_Low                                                 claudin_subtype_Basal                                             0.025569
# claudin_subtype_Basal                                           cellularity_Low                                                   0.025569
# cellularity_Moderate                                            progesterone_receptors_status                                     0.025416
# progesterone_receptors_status                                   cellularity_Moderate                                              0.025416
# vital_status_Died of Disease                                    cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.024793
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           vital_status_Died of Disease                                      0.024793
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  CT_responde                                                       0.024508
# CT_responde                                                     cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.024508
# claudin_subtype_Normal                                          cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma    0.024460
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  claudin_subtype_Normal                                            0.024460
# CT_responde                                                     country_Canada                                                    0.023321
# country_Canada                                                  CT_responde                                                       0.023321
#                                                                 cellularity_Low                                                   0.023116
# cellularity_Low                                                 country_Canada                                                    0.023116
# overall_survival_time_months                                    cancer_type_detailed_Breast                                       0.022597
# cancer_type_detailed_Breast                                     overall_survival_time_months                                      0.022597
# cellularity_High                                                her2_status                                                       0.022558
# her2_status                                                     cellularity_High                                                  0.022558
# cellularity_Moderate                                            menopausal_state                                                  0.022009
# menopausal_state                                                cellularity_Moderate                                              0.022009
# progesterone_receptors_status                                   cancer_type_detailed_Metaplastic Breast Cancer                    0.021945
# cancer_type_detailed_Metaplastic Breast Cancer                  progesterone_receptors_status                                     0.021945
# tumor_size_mm                                                   claudin_subtype_Normal                                            0.021873
# claudin_subtype_Normal                                          tumor_size_mm                                                     0.021873
# vital_status_Died of Other Causes                               cancer_type_detailed_Invasive Breast Carcinoma                    0.021284
# cancer_type_detailed_Invasive Breast Carcinoma                  vital_status_Died of Other Causes                                 0.021284
# claudin_subtype_NC                                              vital_status_Died of Disease                                      0.020879
# vital_status_Died of Disease                                    claudin_subtype_NC                                                0.020879
# claudin_subtype_claudin-low                                     cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.020651
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           claudin_subtype_claudin-low                                       0.020651
# age_at_diagnosis_years                                          cancer_type_detailed_Breast                                       0.020551
# cancer_type_detailed_Breast                                     age_at_diagnosis_years                                            0.020551
# estrogen_receptors_ihc                                          claudin_subtype_Normal                                            0.020538
# claudin_subtype_Normal                                          estrogen_receptors_ihc                                            0.020538
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          claudin_subtype_NC                                                0.020383
# claudin_subtype_NC                                              cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.020383
# cancer_type_detailed_Metaplastic Breast Cancer                  CT_responde                                                       0.020221
# CT_responde                                                     cancer_type_detailed_Metaplastic Breast Cancer                    0.020221
# country_Mexico                                                  claudin_subtype_Her2                                              0.019619
# claudin_subtype_Her2                                            country_Mexico                                                    0.019619
# progesterone_receptors_status                                   cancer_type_detailed_Invasive Breast Carcinoma                    0.019560
# cancer_type_detailed_Invasive Breast Carcinoma                  progesterone_receptors_status                                     0.019560
# age_at_diagnosis_years                                          country_Mexico                                                    0.019076
# country_Mexico                                                  age_at_diagnosis_years                                            0.019076
#                                                                 cellularity_Moderate                                              0.019057
# cellularity_Moderate                                            country_Mexico                                                    0.019057
# claudin_subtype_Basal                                           vital_status_Living                                               0.018420
# vital_status_Living                                             claudin_subtype_Basal                                             0.018420
# claudin_subtype_claudin-low                                     country_Canada                                                    0.018115
# country_Canada                                                  claudin_subtype_claudin-low                                       0.018115
# claudin_subtype_LumB                                            cancer_type_detailed_Breast Invasive Ductal Carcinoma             0.017891
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           claudin_subtype_LumB                                              0.017891
# cellularity_High                                                country_Canada                                                    0.017363
# country_Canada                                                  cellularity_High                                                  0.017363
# country_Mexico                                                  tumor_size_mm                                                     0.016697
# tumor_size_mm                                                   country_Mexico                                                    0.016697
# cellularity_Moderate                                            country_USA                                                       0.016569
# country_USA                                                     cellularity_Moderate                                              0.016569
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          CT_responde                                                       0.015896
# CT_responde                                                     cancer_type_detailed_Breast Invasive Lobular Carcinoma            0.015896
# claudin_subtype_claudin-low                                     overall_survival_time_months                                      0.015809
# overall_survival_time_months                                    claudin_subtype_claudin-low                                       0.015809
# progesterone_receptors_status                                   claudin_subtype_NC                                                0.015514
# claudin_subtype_NC                                              progesterone_receptors_status                                     0.015514
# tumor_size_mm                                                   CT_responde                                                       0.015251
# CT_responde                                                     tumor_size_mm                                                     0.015251
# menopausal_state                                                cancer_type_detailed_Invasive Breast Carcinoma                    0.014961
# cancer_type_detailed_Invasive Breast Carcinoma                  menopausal_state                                                  0.014961
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   country_Mexico                                                    0.014939
# country_Mexico                                                  cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma     0.014939
# claudin_subtype_LumB                                            cancer_type_detailed_Breast                                       0.014655
# cancer_type_detailed_Breast                                     claudin_subtype_LumB                                              0.014655
# lymph_nodes_examined_positive                                   cancer_type_detailed_Invasive Breast Carcinoma                    0.014447
# cancer_type_detailed_Invasive Breast Carcinoma                  lymph_nodes_examined_positive                                     0.014447
# lymph_nodes_examined_positive                                   claudin_subtype_Basal                                             0.014362
# claudin_subtype_Basal                                           lymph_nodes_examined_positive                                     0.014362
# country_USA                                                     progesterone_receptors_status                                     0.014359
# ...
# vital_status_Died of Disease                                    estrogen_receptors_ihc                                           -0.107606
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  her2_status                                                      -0.110028
# her2_status                                                     cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma   -0.110028
# vital_status_Died of Disease                                    progesterone_receptors_status                                    -0.112065
# progesterone_receptors_status                                   vital_status_Died of Disease                                     -0.112065
# overall_survival_time_months                                    her2_status                                                      -0.112491
# her2_status                                                     overall_survival_time_months                                     -0.112491
# cellularity_High                                                claudin_subtype_claudin-low                                      -0.113309
# claudin_subtype_claudin-low                                     cellularity_High                                                 -0.113309
# claudin_subtype_Basal                                           claudin_subtype_claudin-low                                      -0.113409
# claudin_subtype_claudin-low                                     claudin_subtype_Basal                                            -0.113409
# claudin_subtype_LumB                                            cellularity_Low                                                  -0.114602
# cellularity_Low                                                 claudin_subtype_LumB                                             -0.114602
# progesterone_receptors_status                                   tumor_size_mm                                                    -0.117233
# tumor_size_mm                                                   progesterone_receptors_status                                    -0.117233
# claudin_subtype_LumA                                            cancer_type_detailed_Breast Invasive Ductal Carcinoma            -0.117621
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           claudin_subtype_LumA                                             -0.117621
# claudin_subtype_claudin-low                                     claudin_subtype_Her2                                             -0.117635
# claudin_subtype_Her2                                            claudin_subtype_claudin-low                                      -0.117635
# claudin_subtype_Basal                                           claudin_subtype_Her2                                             -0.122291
# claudin_subtype_Her2                                            claudin_subtype_Basal                                            -0.122291
# her2_status                                                     claudin_subtype_LumB                                             -0.123428
# claudin_subtype_LumB                                            her2_status                                                      -0.123428
# claudin_subtype_LumA                                            tumor_size_mm                                                    -0.128458
# tumor_size_mm                                                   claudin_subtype_LumA                                             -0.128458
# claudin_subtype_Basal                                           menopausal_state                                                 -0.143389
# menopausal_state                                                claudin_subtype_Basal                                            -0.143389
# overall_survival_time_months                                    age_at_diagnosis_years                                           -0.150512
# age_at_diagnosis_years                                          overall_survival_time_months                                     -0.150512
# estrogen_receptors_ihc                                          cancer_type_detailed_Breast Invasive Ductal Carcinoma            -0.154521
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           estrogen_receptors_ihc                                           -0.154521
# claudin_subtype_Normal                                          claudin_subtype_LumB                                             -0.155052
# claudin_subtype_LumB                                            claudin_subtype_Normal                                           -0.155052
# claudin_subtype_Normal                                          cellularity_High                                                 -0.156750
# cellularity_High                                                claudin_subtype_Normal                                           -0.156750
# claudin_subtype_Basal                                           age_at_diagnosis_years                                           -0.158616
# age_at_diagnosis_years                                          claudin_subtype_Basal                                            -0.158616
# vital_status_Living                                             tumor_size_mm                                                    -0.165363
# tumor_size_mm                                                   vital_status_Living                                              -0.165363
# vital_status_Living                                             lymph_nodes_examined_positive                                    -0.165752
# lymph_nodes_examined_positive                                   vital_status_Living                                              -0.165752
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           cancer_type_detailed_Invasive Breast Carcinoma                   -0.170946
# cancer_type_detailed_Invasive Breast Carcinoma                  cancer_type_detailed_Breast Invasive Ductal Carcinoma            -0.170946
# menopausal_state                                                vital_status_Living                                              -0.178551
# vital_status_Living                                             menopausal_state                                                 -0.178551
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           cancer_type_detailed_Breast                                      -0.182850
# cancer_type_detailed_Breast                                     cancer_type_detailed_Breast Invasive Ductal Carcinoma            -0.182850
# claudin_subtype_LumA                                            vital_status_Died of Disease                                     -0.184461
# vital_status_Died of Disease                                    claudin_subtype_LumA                                             -0.184461
# claudin_subtype_claudin-low                                     claudin_subtype_LumB                                             -0.188330
# claudin_subtype_LumB                                            claudin_subtype_claudin-low                                      -0.188330
# overall_survival_time_months                                    tumor_size_mm                                                    -0.189875
# tumor_size_mm                                                   overall_survival_time_months                                     -0.189875
# claudin_subtype_LumB                                            claudin_subtype_Basal                                            -0.195786
# claudin_subtype_Basal                                           claudin_subtype_LumB                                             -0.195786
# claudin_subtype_LumB                                            claudin_subtype_Her2                                             -0.203080
# claudin_subtype_Her2                                            claudin_subtype_LumB                                             -0.203080
# cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   cancer_type_detailed_Breast Invasive Ductal Carcinoma            -0.204658
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma    -0.204658
# claudin_subtype_Normal                                          claudin_subtype_LumA                                             -0.206661
# claudin_subtype_LumA                                            claudin_subtype_Normal                                           -0.206661
# progesterone_receptors_status                                   claudin_subtype_claudin-low                                      -0.215874
# claudin_subtype_claudin-low                                     progesterone_receptors_status                                    -0.215874
# claudin_subtype_Her2                                            progesterone_receptors_status                                    -0.216650
# progesterone_receptors_status                                   claudin_subtype_Her2                                             -0.216650
# claudin_subtype_claudin-low                                     estrogen_receptors_ihc                                           -0.225519
# estrogen_receptors_ihc                                          claudin_subtype_claudin-low                                      -0.225519
#                                                                 her2_status                                                      -0.237041
# her2_status                                                     estrogen_receptors_ihc                                           -0.237041
# overall_survival_time_months                                    lymph_nodes_examined_positive                                    -0.242156
# lymph_nodes_examined_positive                                   overall_survival_time_months                                     -0.242156
# claudin_subtype_Her2                                            estrogen_receptors_ihc                                           -0.250902
# estrogen_receptors_ihc                                          claudin_subtype_Her2                                             -0.250902
# claudin_subtype_claudin-low                                     claudin_subtype_LumA                                             -0.251017
# claudin_subtype_LumA                                            claudin_subtype_claudin-low                                      -0.251017
# progesterone_receptors_status                                   her2_status                                                      -0.258843
# her2_status                                                     progesterone_receptors_status                                    -0.258843
# claudin_subtype_Basal                                           claudin_subtype_LumA                                             -0.260953
# claudin_subtype_LumA                                            claudin_subtype_Basal                                            -0.260953
# claudin_subtype_Her2                                            claudin_subtype_LumA                                             -0.270676
# claudin_subtype_LumA                                            claudin_subtype_Her2                                             -0.270676
# cellularity_Moderate                                            cellularity_Low                                                  -0.272126
# cellularity_Low                                                 cellularity_Moderate                                             -0.272126
# her2_status                                                     claudin_subtype_LumA                                             -0.281206
# claudin_subtype_LumA                                            her2_status                                                      -0.281206
# age_at_diagnosis_years                                          vital_status_Living                                              -0.306852
# vital_status_Living                                             age_at_diagnosis_years                                           -0.306852
# claudin_subtype_Basal                                           progesterone_receptors_status                                    -0.315950
# progesterone_receptors_status                                   claudin_subtype_Basal                                            -0.315950
# cellularity_Low                                                 cellularity_High                                                 -0.352596
# cellularity_High                                                cellularity_Low                                                  -0.352596
# country_USA                                                     country_Mexico                                                   -0.400153
# country_Mexico                                                  country_USA                                                      -0.400153
# vital_status_Died of Disease                                    vital_status_Died of Other Causes                                -0.406301
# vital_status_Died of Other Causes                               vital_status_Died of Disease                                     -0.406301
# claudin_subtype_LumB                                            claudin_subtype_LumA                                             -0.433346
# claudin_subtype_LumA                                            claudin_subtype_LumB                                             -0.433346
# vital_status_Died of Disease                                    overall_survival_time_months                                     -0.440262
# overall_survival_time_months                                    vital_status_Died of Disease                                     -0.440262
# vital_status_Died of Other Causes                               vital_status_Living                                              -0.492924
# vital_status_Living                                             vital_status_Died of Other Causes                                -0.492924
# estrogen_receptors_ihc                                          claudin_subtype_Basal                                            -0.514597
# claudin_subtype_Basal                                           estrogen_receptors_ihc                                           -0.514597
# country_USA                                                     country_Canada                                                   -0.547653
# country_Canada                                                  country_USA                                                      -0.547653
# country_Mexico                                                  country_Canada                                                   -0.547653
# country_Canada                                                  country_Mexico                                                   -0.547653
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           cancer_type_detailed_Breast Invasive Lobular Carcinoma           -0.549458
# cancer_type_detailed_Breast Invasive Lobular Carcinoma          cancer_type_detailed_Breast Invasive Ductal Carcinoma            -0.549458
# vital_status_Living                                             vital_status_Died of Disease                                     -0.594744
# vital_status_Died of Disease                                    vital_status_Living                                              -0.594744
# cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  cancer_type_detailed_Breast Invasive Ductal Carcinoma            -0.674302
# cancer_type_detailed_Breast Invasive Ductal Carcinoma           cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma   -0.674302
# cellularity_High                                                cellularity_Moderate                                             -0.804510
# cellularity_Moderate                                            cellularity_High                                                 -0.804510
# dtype: float64

# %% [markdown]
# La sintaxis es la siguiente:
# - **pd.set_option('display.max_columns', None)**: Permite mostrar todas las columnas de la matriz de correlación. Si no usamos esto, solo veremos unas cuantas comparaciones y no todo.
# - **matriz_correlacion = bd_5.corr()**: No hace explicar, o sí?... Bueno, calcula la matriz de correlación de la base de datos "bd_5".
# - **sorted_correlacion = matriz_correlacion.unstack().sort_values(ascending=False)**: Adivina... si, ordena la matriz de correlación de forma descendente, es decir, del 1 al -1.
#
# Con lo anterior, obtuvimos muchas comparaciones, las que son perfectamente correlacionadas es porque fueron comparadas consigo mismas, o con algunas variable que puede decirse que es exactamente lo mismo. Con esto, tenemos la difícil tarea de decidir qué variables eliminar, o si es necesario hacerlo, ya que puede haber correlaciones muy altas, pero son variables diferentes... es por eso que este proceso puede llevar meses en valorar.
#
# Ahora, podemos detectar que, "claundin_subtype_her2" y "her2_status" tienen una correlación de 0.78, lo que significa que son muy similares, por lo que podemos eliminar una de ellas, la que nos aporte menos información. Naturalmente, es un tema de qué hablar con el equipo de trabajo, ya que puede haber información valiosa en dicha variable.
#
# Vamos a dar otro vistazo a nuestra base de datos, y ver que todo está en orden.

# %%
bd_6 = bd_5.drop(columns=['her2_status'])
bd_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 31 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   overall_survival_time_months                                    1830 non-null   float64
#  1   age_at_diagnosis_years                                          1830 non-null   float64
#  2   lymph_nodes_examined_positive                                   1830 non-null   int64
#  3   estrogen_receptors_ihc                                          1830 non-null   int64
#  4   menopausal_state                                                1830 non-null   int64
#  5   progesterone_receptors_status                                   1830 non-null   int64
#  6   tumor_size_mm                                                   1830 non-null   float64
#  7   CT_responde                                                     1830 non-null   int64
#  8   country_Canada                                                  1830 non-null   int32
#  9   country_Mexico                                                  1830 non-null   int32
#  10  country_USA                                                     1830 non-null   int32
#  11  cellularity_High                                                1830 non-null   int32
#  12  cellularity_Low                                                 1830 non-null   int32
#  13  cellularity_Moderate                                            1830 non-null   int32
#  14  claudin_subtype_Basal                                           1830 non-null   int32
#  15  claudin_subtype_Her2                                            1830 non-null   int32
#  16  claudin_subtype_LumA                                            1830 non-null   int32
#  17  claudin_subtype_LumB                                            1830 non-null   int32
#  18  claudin_subtype_NC                                              1830 non-null   int32
#  19  claudin_subtype_Normal                                          1830 non-null   int32
#  20  claudin_subtype_claudin-low                                     1830 non-null   int32
#  21  vital_status_Died of Disease                                    1830 non-null   int32
#  22  vital_status_Died of Other Causes                               1830 non-null   int32
#  23  vital_status_Living                                             1830 non-null   int32
#  24  cancer_type_detailed_Breast                                     1830 non-null   int32
#  25  cancer_type_detailed_Breast Invasive Ductal Carcinoma           1830 non-null   int32
#  26  cancer_type_detailed_Breast Invasive Lobular Carcinoma          1830 non-null   int32
#  27  cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   1830 non-null   int32
#  28  cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  1830 non-null   int32
#  29  cancer_type_detailed_Invasive Breast Carcinoma                  1830 non-null   int32
#  30  cancer_type_detailed_Metaplastic Breast Cancer                  1830 non-null   int32
# dtypes: float64(3), int32(23), int64(5)
# memory usage: 278.9 KB

# %% [markdown]
# Muy bien, nuestra base de datos tiene unos pequeños ajustes, vamos a hacer un pequeño modelo de ML. Para esto, es una buena práctica mover nuestra variable predictora al final de la base de datos. Eso lo haremos con el siguiente código.

# %%
col_to_move = bd_6.columns[7]
cols = list(bd_6.columns)
cols.insert(30, cols.pop(cols.index(col_to_move)))
bd_6 = bd_6[cols]

# %% [markdown]
# De manera general, lo que hicimos fue crear un objeto con la columna a mover, que es "CT_responde", y luego la eliminamos de la base de datos. Posteriormente, la agregamos al final de la base de datos.
#
# Nuevamente, un resumen para ver que está bien.

# %%
bd_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 31 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   overall_survival_time_months                                    1830 non-null   float64
#  1   age_at_diagnosis_years                                          1830 non-null   float64
#  2   lymph_nodes_examined_positive                                   1830 non-null   int64
#  3   estrogen_receptors_ihc                                          1830 non-null   int64
#  4   menopausal_state                                                1830 non-null   int64
#  5   progesterone_receptors_status                                   1830 non-null   int64
#  6   tumor_size_mm                                                   1830 non-null   float64
#  7   country_Canada                                                  1830 non-null   int32
#  8   country_Mexico                                                  1830 non-null   int32
#  9   country_USA                                                     1830 non-null   int32
#  10  cellularity_High                                                1830 non-null   int32
#  11  cellularity_Low                                                 1830 non-null   int32
#  12  cellularity_Moderate                                            1830 non-null   int32
#  13  claudin_subtype_Basal                                           1830 non-null   int32
#  14  claudin_subtype_Her2                                            1830 non-null   int32
#  15  claudin_subtype_LumA                                            1830 non-null   int32
#  16  claudin_subtype_LumB                                            1830 non-null   int32
#  17  claudin_subtype_NC                                              1830 non-null   int32
#  18  claudin_subtype_Normal                                          1830 non-null   int32
#  19  claudin_subtype_claudin-low                                     1830 non-null   int32
#  20  vital_status_Died of Disease                                    1830 non-null   int32
#  21  vital_status_Died of Other Causes                               1830 non-null   int32
#  22  vital_status_Living                                             1830 non-null   int32
#  23  cancer_type_detailed_Breast                                     1830 non-null   int32
#  24  cancer_type_detailed_Breast Invasive Ductal Carcinoma           1830 non-null   int32
#  25  cancer_type_detailed_Breast Invasive Lobular Carcinoma          1830 non-null   int32
#  26  cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma   1830 non-null   int32
#  27  cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  1830 non-null   int32
#  28  cancer_type_detailed_Invasive Breast Carcinoma                  1830 non-null   int32
#  29  cancer_type_detailed_Metaplastic Breast Cancer                  1830 non-null   int32
#  30  CT_responde                                                     1830 non-null   int64
# dtypes: float64(3), int32(23), int64(5)
# memory usage: 278.9 KB

# %% [markdown]
# Perfecto, ya tenemos nuestra base de datos lista para hacer un modelo de ML. En este caso, vamos a hacer un modelo de máquinas de soporte vectorial, que es un modelo de clasificación.
#
# Respecto a la sintaxis, no me detendré a explicarla, solo se mencionará que existen muchos argumentos para hacer ajustes, y cada uno de ellos puede modificar el modelo de forma significativa. Por lo que es importante leer la documentación de la librería para saber qué hace cada argumento.
#
# Otro punto, es por cuestiones de autorìa... jajaja, sin embargo, dentro del código, se encuentra una pequeña explicación de lo que hace de forma general cada argumento.

# %%
from sklearn import model_selection, svm

target = bd_6['CT_responde']
data = bd_6.iloc[:, 0:29]

# Definir una lista de diferentes valores de test_size
sizes = np.arange(0.1, 0.3, 0.05)

# Lista para almacenar los resultados
resultados = []

# Parámetros a ajustar
parametros = {
    'C': [0.1, 1.0, 10.0],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
    'max_iter': [100]
}

# Iterar sobre los diferentes valores de test_size
for test_size in sizes:
    # División de datos en entrenamiento y prueba
    x_train, x_test, y_train, y_test = model_selection.train_test_split(data, target, test_size=test_size, random_state=1, stratify=target)

    # Ajuste del modelo Support Vector Machine (SVM)
    for C in parametros['C']:
        for kernel in parametros['kernel']:
            for gamma in parametros['gamma']:
                for max_iter in parametros['max_iter']:
                    classifier = svm.SVC(C=C, kernel=kernel, gamma=gamma, max_iter=max_iter)
                    model = classifier.fit(x_train, y_train)

                    # Puntuación en el conjunto de prueba
                    score = model.score(x_test, y_test)

                    # Agregar resultados a la lista
                    resultados.append({
                        "Test Size": test_size,
                        "C": C,
                        "Kernel": kernel,
                        "Gamma": gamma,
                        "Max Iter": max_iter,
                        "Model Score": score,                        
                    })

# Ordenar la lista de resultados por el puntaje del modelo (descendente)
resultados_ordenados = sorted(resultados, key=lambda x: x["Model Score"], reverse=True)

# Imprimir los resultados ordenados
for resultado in resultados_ordenados[:5]:
    print(resultado)
# Out:
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Hack\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'Test Size': 0.1, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5956284153005464}
# {'Test Size': 0.1, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5846994535519126}
# {'Test Size': 0.1, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5846994535519126}
# {'Test Size': 0.15000000000000002, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5781818181818181}
# {'Test Size': 0.15000000000000002, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5781818181818181}
# {'Test Size': 0.1, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5737704918032787}
# {'Test Size': 0.20000000000000004, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5722070844686649}
# {'Test Size': 0.25000000000000006, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5720524017467249}
# {'Test Size': 0.15000000000000002, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5709090909090909}
# {'Test Size': 0.25000000000000006, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5698689956331878}
# {'Test Size': 0.25000000000000006, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5698689956331878}
# {'Test Size': 0.20000000000000004, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5694822888283378}
# {'Test Size': 0.20000000000000004, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5694822888283378}
# {'Test Size': 0.20000000000000004, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5694822888283378}
# {'Test Size': 0.25000000000000006, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5676855895196506}
# {'Test Size': 0.25000000000000006, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5676855895196506}
# {'Test Size': 0.25000000000000006, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5655021834061136}
# {'Test Size': 0.1, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5573770491803278}
# {'Test Size': 0.1, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5573770491803278}
# {'Test Size': 0.1, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5573770491803278}
# {'Test Size': 0.1, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5573770491803278}
# {'Test Size': 0.15000000000000002, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5563636363636364}
# {'Test Size': 0.25000000000000006, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5545851528384279}
# {'Test Size': 0.25000000000000006, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5545851528384279}
# {'Test Size': 0.25000000000000006, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5502183406113537}
# {'Test Size': 0.25000000000000006, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5480349344978166}
# {'Test Size': 0.20000000000000004, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5422343324250681}
# {'Test Size': 0.1, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5300546448087432}
# {'Test Size': 0.1, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5300546448087432}
# {'Test Size': 0.15000000000000002, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5236363636363637}
# {'Test Size': 0.15000000000000002, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5236363636363637}
# {'Test Size': 0.15000000000000002, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.5236363636363637}
# {'Test Size': 0.15000000000000002, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.5236363636363637}
# {'Test Size': 0.25000000000000006, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4868995633187773}
# {'Test Size': 0.15000000000000002, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.4763636363636364}
# {'Test Size': 0.15000000000000002, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4763636363636364}
# {'Test Size': 0.15000000000000002, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4727272727272727}
# {'Test Size': 0.1, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.46994535519125685}
# {'Test Size': 0.1, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.46994535519125685}
# {'Test Size': 0.1, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.46994535519125685}
# {'Test Size': 0.20000000000000004, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.4659400544959128}
# {'Test Size': 0.20000000000000004, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4659400544959128}
# {'Test Size': 0.20000000000000004, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.4659400544959128}
# {'Test Size': 0.20000000000000004, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4659400544959128}
# {'Test Size': 0.15000000000000002, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.46545454545454545}
# {'Test Size': 0.15000000000000002, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.46545454545454545}
# {'Test Size': 0.15000000000000002, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.46545454545454545}
# {'Test Size': 0.1, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.4644808743169399}
# {'Test Size': 0.1, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.4644808743169399}
# {'Test Size': 0.25000000000000006, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4606986899563319}
# {'Test Size': 0.25000000000000006, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4606986899563319}
# {'Test Size': 0.25000000000000006, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4606986899563319}
# {'Test Size': 0.20000000000000004, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.4604904632152589}
# {'Test Size': 0.20000000000000004, 'C': 0.1, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4604904632152589}
# {'Test Size': 0.15000000000000002, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4581818181818182}
# {'Test Size': 0.25000000000000006, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.45633187772925765}
# {'Test Size': 0.25000000000000006, 'C': 1.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.45633187772925765}
# {'Test Size': 0.25000000000000006, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.45633187772925765}
# {'Test Size': 0.25000000000000006, 'C': 10.0, 'Kernel': 'linear', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.45633187772925765}
# {'Test Size': 0.20000000000000004, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.4550408719346049}
# {'Test Size': 0.15000000000000002, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.45454545454545453}
# {'Test Size': 0.15000000000000002, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.45454545454545453}
# {'Test Size': 0.15000000000000002, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.45454545454545453}
# {'Test Size': 0.1, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.453551912568306}
# {'Test Size': 0.20000000000000004, 'C': 0.1, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.45231607629427795}
# {'Test Size': 0.20000000000000004, 'C': 1.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.45231607629427795}
# {'Test Size': 0.20000000000000004, 'C': 10.0, 'Kernel': 'poly', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.45231607629427795}
# {'Test Size': 0.20000000000000004, 'C': 0.1, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.44959128065395093}
# {'Test Size': 0.20000000000000004, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.44959128065395093}
# {'Test Size': 0.20000000000000004, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.43869209809264303}
# {'Test Size': 0.1, 'C': 1.0, 'Kernel': 'rbf', 'Gamma': 'auto', 'Max Iter': 100, 'Model Score': 0.4262295081967213}
# {'Test Size': 0.1, 'C': 10.0, 'Kernel': 'rbf', 'Gamma': 'scale', 'Max Iter': 100, 'Model Score': 0.41530054644808745}

# %% [markdown]
# A modo de resumen, pusimos los datos importantes. Con esto, podemos saber cuáles fueron las características más útiles para el modelo y el dato más relevante (por ahora y para el taller), que es el puntaje del modelo. Este valor nos dice qué tan bueno es nuestro modelo, y mientras más cercano a 1, mejor es. El primer resultado nos dice que nuestro modelo tiene una certeza del 59% para predecir correctamente cuáles pacientes van a responder al tratamiento de quimioterapia basado en la base de datos que utilizamos.
#
# Sin embargo, no es tan bueno, es casi como echarse un volado. Por esto, vamos a probar otro modelito, que es el de "random forest".

# %%
import numpy as np
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

target = bd_6['CT_responde']
data = bd_6.iloc[:, 0:29]

# Definir una lista de diferentes valores de test_size
sizes = np.arange(0.1, 0.3, 0.05)

# Lista para almacenar los resultados
resultados = []

# Parámetros a ajustar
parametros = {
    'n_estimators': [50],
    'max_depth': [None, 10],
    'min_samples_split': [5, 15],
    'min_samples_leaf': [2, 8]
}

# Iterar sobre los diferentes valores de test_size
for test_size in sizes:
    # División de datos en entrenamiento y prueba
    x_train, x_test, y_train, y_test = model_selection.train_test_split(data, target, test_size=test_size, random_state=1, stratify=target)

    # Ajuste del modelo Random Forest
    for n_estimators in parametros['n_estimators']:
        for max_depth in parametros['max_depth']:
            for min_samples_split in parametros['min_samples_split']:
                for min_samples_leaf in parametros['min_samples_leaf']:
                    classifier = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth,
                                                        min_samples_split=min_samples_split,
                                                        min_samples_leaf=min_samples_leaf)
                    model = classifier.fit(x_train, y_train)

                    # Puntuación en el conjunto de prueba
                    score = model.score(x_test, y_test)

                    # Agregar resultados a la lista
                    resultados.append({
                        "Test Size": test_size,
                        "n_estimators": n_estimators,
                        "max_depth": max_depth,
                        "min_samples_split": min_samples_split,
                        "min_samples_leaf": min_samples_leaf,
                        "Model Score": score,
                    })

# Ordenar la lista de resultados por el puntaje del modelo (descendente)
resultados_ordenados = sorted(resultados, key=lambda x: x["Model Score"], reverse=True)

# Imprimir los resultados ordenados
for resultado in resultados_ordenados[:5]:
    print(resultado)
# Out:
# {'Test Size': 0.15000000000000002, 'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 8, 'Model Score': 0.6363636363636364}
# {'Test Size': 0.20000000000000004, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 8, 'Model Score': 0.6348773841961853}
# {'Test Size': 0.25000000000000006, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 2, 'Model Score': 0.6244541484716157}
# {'Test Size': 0.20000000000000004, 'n_estimators': 50, 'max_depth': None, 'min_samples_split': 15, 'min_samples_leaf': 8, 'Model Score': 0.6185286103542235}
# {'Test Size': 0.15000000000000002, 'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 2, 'Model Score': 0.6145454545454545}
# {'Test Size': 0.15000000000000002, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 2, 'Model Score': 0.6145454545454545}
# {'Test Size': 0.15000000000000002, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 8, 'Model Score': 0.6145454545454545}
# {'Test Size': 0.20000000000000004, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 8, 'Model Score': 0.6130790190735694}
# {'Test Size': 0.1, 'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 8, 'Model Score': 0.6120218579234973}
# {'Test Size': 0.1, 'n_estimators': 50, 'max_depth': None, 'min_samples_split': 15, 'min_samples_leaf': 8, 'Model Score': 0.6120218579234973}

# %% [markdown]
# Listo!!! Ya tenemos nuestro modelo de random forest, y nos arrojó un resultado de 0.63, lo que significa que es un poco mejor que el modelo de máquinas de soporte vectorial. Podríamos evaluar las variables, dar una mejor limpieza, ampliar la base de datos, buscar más variables, usar diferentes modelos, darles mejores parámetros, etc. Pero por ahora, es resultado aceptable.
